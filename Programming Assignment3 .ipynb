# %% [markdown]
# 1. Write a Python program to print &quot;Hello Python&quot;?

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# 2. Write a Python program to do arithmetical operations addition and division.?

# %%
try : 
  def fucnt(a,b):
    print(a+b)
    print(a/b)
    print(a*b)
    print(a/b)
except Exception as e:
  print("here is your error please check" , e)

fucnt(3,9)
# Out:
# 12
# 0.3333333333333333
# 27
# 0.3333333333333333

# %% [markdown]
# 3. Write a Python program to find the area of a triangle?

# %%
# area of trainagle when 3 sides are given through herons formula 
try :
  def heron(a,b,c):
    s = float((a+b+c)/2)
    
    j= s-a 
    k= s-b
    l= s-c
    m= j*k*l
    
    a = (m*s)**0.5
    
    print("your semi perimetre =", s,"your area of traingle=", a) 
# area of traingle when the base and height are provided
  def AOT_height(base, height):
       return (base*height)/2

except Exception as e:
  print(e)

  


heron(4,5,3)
AOT_height(5,7)
# Out:
# your semi perimetre = 6.0 your area of traingle= 6.0
# 17.5

# %% [markdown]
# 4. Write a Python program to swap two variables?

# %%
try :
  
  def swap(A,B):
    
    A,B = B,A
    return A,B
except Exception as e:
  print(e)

swap(8,9)
# Out:
# (9, 8)

# %% [markdown]
# 5. Write a Python program to generate a random number?

# %%
import random
try : 
  a = int(input())
  b = int(input())
  
  
  for i in range(a,b+1,1):
    c = random.randint(a, b+1)
    
    print(c, end = " ")

   
 
except Exception as e:
  print(e)
# Out:
# 8
# 20
# 21 9 19 8 17 12 10 9 18 13 10 15 10
