# %%
ANS1- "*, -,/, + 6 are the mathematical operators here ". "hello", -87.8, and 6 are the values.

# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
# &#39;hello&#39;
# -87.8
# -
# /
# +
# 6

# %%
ANS2 - string is use for describing and interprting the values that are not digits or numbers it can be script. Varibale is just a entity that taht we create to store the values it could store both numbers and alpahbatic characters to entire paraghraphs.

# %% [markdown]
# 2. What is the difference between string and variable?

# %%
Ans2 - it include the integers which is set of whole numbers, string which is set of aplhabtic characters or 97 (in ASCII, 97 is a lower case 'a'), and float which includes the data which is fraction or decimal form.

# %% [markdown]
# 3. Describe three different data types.

# %%
Ans4 - experession is combination of methods, variables and operatores in coding that we write to perform any task.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %%
ANS5 - expression refers to use of multiple entity such as varibales, values, methods to perform a task or get and output. While the Statement is just a standalone line that can be executed. For ex- spam = 10 is statement since it only uses one line of to hold the value of spam variable as 10.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %%
ANS 6 - bacon = 22 
bacon + 1
# lets call the bacon again and check what it holds 
print(bacon)
#so clearly the bacon hold the value 22 only. the line bacon + 1 had no effect as we did not store the value in bacon. if we use following line of bacon = bacon + 1 then we can increment the value of bacon. 
bacon = 22 
bacon = bacon + 1
print(bacon)
# Out:
# 22
# 23

# %% [markdown]
# 6.After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %%
#ans 6 - 
"spam"+'spamspam''spam'*3
 #it will conacatenate the both string after thricing the "spam"*3
# Out:
# 'spamspamspamspamspamspamspamspamspamspam'

# %% [markdown]
# 7. What should the values of the following two terms be?
# &#39;spam&#39; + &#39;spamspam&#39;
# &#39;spam&#39; * 3

# %%
# ans 8 - 
egg is valid variable beacuse we use to string character to hold the value. However, 100 cant be the valid for variable as it is integer and is predefine in python.

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %%
#ans9 - 
a= 884565
b= "wfasc"
print(int(a), type(int(a)))
print(str(a),type(float(a)))
print(str(a),type(str(a)))
#print(int(b)) 
#int(),str(),float()can be use to get the desired data type version of any value. However, you cannot use float(), int() on string.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-64f780428657> in <module>()
#       2 a= 884565
#       3 b= "wfasc"
# ----> 4 print(int(b))
#       5 print(int(a), type(int(a)))
#       6 print(str(a),type(float(a)))
#
# ValueError: invalid literal for int() with base 10: 'wfasc'

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?

# %%
#ans 10 -
try: 
   print('I have eaten ' + 99 + ' burritos.')
# 99 is integer so can can only concatenate str (not "int") to str.
finally:

   print ("I have eaten"+ "99"+"burritos")
   print('I have eaten' +str(99) + ' burritos.') #if you have 99 stored in variable a= 99 so you can use str(a) to concatenate as double quote will not work that time.
# Out:
# I have eaten99burritos
# I have eaten 99 burritos.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-965e42139736> in <module>()
#       1 #ans 10 -
#       2 try:
# ----> 3    print('I have eaten ' + 99 + ' burritos.')
#       4 # 99 is integer so can can only concatenate str (not "int") to str.
#       5 finally:
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# &#39;I have eaten &#39; + 99 + &#39; burritos.&#39;
